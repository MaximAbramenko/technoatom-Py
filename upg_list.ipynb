# %%
class upg_list(list):
    
    def __add__(self, other):
        g = upg_list()
        m_len = len(self)
        if len(self) < len(other):
            m_len = len(other)
            copy = self[:]
            for _ in range(len(other) - len(self)):
                copy.append(0)
            for i in range(m_len):
                g.append(copy[i] + other[i])
        elif len(self) > len(other):
            copy = other[:]
            for _ in range(m_len - len(other)):
                copy.append(0)
            for i in range(m_len):
                g.append(copy[i] + self[i])
        else:
            for i in range(m_len):
                g.append(other[i] + self[i])
        return g
    
    def __sub__(self, other):
        g = upg_list()
        m_len = len(self)
        if len(self) < len(other):
            m_len = len(other)
            copy = self[:]
            for _ in range(len(other) - len(self)):
                copy.append(0)
            for i in range(m_len):
                g.append(copy[i] - other[i])
        elif len(self) > len(other):
            copy = other[:]
            for _ in range(m_len - len(other)):
                copy.append(0)
            for i in range(m_len):
                g.append(copy[i] - self[i])
        else:
            for i in range(m_len):
                g.append(other[i] - self[i])
        return g
    
    def __lt__(self, other):
        return sum(self) < sum(other)

    def __le__(self, other):
        return sum(self) <= sum(other)
    
    def __eq__(self, other):
        return sum(self) == sum(other)
    
    def __ne__(self, other):
        return sum(self) != sum(other)
    
    def __gt__(self, other):
        return sum(self) > sum(other)
    
    def __ge__(self, other):
        return sum(self) >= sum(other)
    
def main():
    a = upg_list([1,2,3,30])
    b = upg_list([4,5,6,8,6,7])
    print(a + b)
    print(b - a)
    print(a - b)
    print(a == b)
    print(a<b)
    print(a>b)
    print(a)
    print(b)
    c = [4, 5, 7]
    print(a + c)
main()
# Out:
# [5, 7, 9, 38, 6, 7]
# [-3, -3, -3, 22, -6, -7]
# [-3, -3, -3, 22, -6, -7]
# True
# False
# False
# [1, 2, 3, 30]
# [4, 5, 6, 8, 6, 7]
# [5, 7, 10, 30]

# %% [markdown]
# 3###
